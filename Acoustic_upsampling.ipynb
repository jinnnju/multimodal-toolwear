# %%
import pandas as pd
from utils import upsample_split_acoustic as us
from utils import upsample_split_acoustic_T4 as us200

# %%
# code for T1, T5
us.process_all(
    input_dir="/home/crois-times/timeseries/YS/Tool Wear Anomaly Detection/data/Dataset_origin/T5/Acoustic_Emission_Data",
    output_root="/home/crois-times/timeseries/projects/tool_wear_havard/splitted_100ms",
    type_name="T5",
    acoustic_subdir="Acoustic"
)
# Out:
# [INFO] Processing Expt_1: /home/crois-times/timeseries/YS/Tool Wear Anomaly Detection/data/Dataset_origin/T5/Acoustic_Emission_Data/Expt_1.csv
# [INFO] Processing Expt_2: /home/crois-times/timeseries/YS/Tool Wear Anomaly Detection/data/Dataset_origin/T5/Acoustic_Emission_Data/Expt_2.csv
# [INFO] Processing Expt_3: /home/crois-times/timeseries/YS/Tool Wear Anomaly Detection/data/Dataset_origin/T5/Acoustic_Emission_Data/Expt_3.csv
# [INFO] Processing Expt_4: /home/crois-times/timeseries/YS/Tool Wear Anomaly Detection/data/Dataset_origin/T5/Acoustic_Emission_Data/Expt_4.csv
# [INFO] Processing Expt_5: /home/crois-times/timeseries/YS/Tool Wear Anomaly Detection/data/Dataset_origin/T5/Acoustic_Emission_Data/Expt_5.csv
# [INFO] Processing Expt_6: /home/crois-times/timeseries/YS/Tool Wear Anomaly Detection/data/Dataset_origin/T5/Acoustic_Emission_Data/Expt_6.csv
# ...

# %%
us200.process_all(
    input_dir="/home/crois-times/timeseries/YS/Tool Wear Anomaly Detection/data/Dataset_origin/T8/Acoustic_Emission_Data",
    output_root="/home/crois-times/timeseries/projects/tool_wear_havard/splitted_100ms",
    type_name="T8",
    acoustic_subdir="Acoustic"
)
# Out:
# [INFO] Processing Expt_1
# [INFO] Processing Expt_2
# [INFO] Processing Expt_3
# [INFO] Processing Expt_4
# [INFO] Processing Expt_5
# [INFO] Processing Expt_6
# [INFO] Processing Expt_7
# [INFO] Processing Expt_8
# [INFO] Processing Expt_9
# [INFO] Processing Expt_10
# [INFO] Processing Expt_11
# [INFO] Processing Expt_12
# [DONE] Saved 2400 CSV files to /home/crois-times/timeseries/projects/tool_wear_havard/splitted_100ms/T8/Acoustic
